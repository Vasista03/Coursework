# %%
import sys
print("Python version:", sys.version)
 
# Check installed modules
help("modules")
 
# Quick version compare
if sys.version_info >= (3, 10):
    print("✅ You’re on a modern Python version!")
else:
    print("⚠️ Consider Upgrading Python.")
# Out:
# Python version: 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]
#
# Please wait a moment while I gather a list of all available modules...
#
# D_1                 compileall          menuinst            snappy
# IPython             concurrent          mimetypes           sndhdr
# OpenSSL             conda               mistune             sniffio
# PIL                 conda_build         mkl                 snowballstemmer
# PyQt5               conda_content_trust mkl_fft             socket
# TBB                 conda_env           mkl_random          socketserver
# __future__          conda_index         mmap                socks
# __hello__           conda_libmamba_solver mmapfile            sockshandler
# __phello__          conda_pack          mmsystem            sortedcontainers
# _abc                conda_package_handling modulefinder        soupsieve
# _aix_support        conda_package_streaming more_itertools      sphinx
# _argon2_cffi_bindings conda_token         mpmath              sphinxify
# _ast                conda_verify        msgpack             sphinxthread
# _asyncio            conf                msilib              spyder
# _bisect             configparser        msvcrt              spyder_kernels
# _black_version      constantly          multidict           sqlalchemy
# _blake2             contextlib          multipledispatch    sqlite3
# _bootsubprocess     contextvars         multiprocessing     sre_compile
# _bz2                contourpy           munkres             sre_constants
# _cffi_backend       cookiecutter        mypy_extensions     sre_parse
# _codecs             copy                nacl                ssl
# _codecs_cn          copyreg             navigator_updater   sspi
# _codecs_hk          cpuinfo             nbclassic           sspicon
# _codecs_iso2022     crypt               nbclient            stack_data
# _codecs_jp          cryptography        nbconvert           stat
# _codecs_kr          cssselect           nbformat            statistics
# _codecs_tw          csv                 nest_asyncio        statsmodels
# _collections        ctypes              netbios             string
# _collections_abc    curl                netrc               stringprep
# _compat_pickle      curses              networkx            struct
# _compression        cwp                 nltk                subprocess
# _contextvars        cycler              nntplib             sunau
# _csv                cytoolz             notebook            sympy
# _ctypes             daal4py             notebook_shim       symtable
# _ctypes_test        dask                nt                  sys
# _datetime           dataclasses         ntpath              sysconfig
# _decimal            datashader          ntsecuritycon       tables
# _distutils_hack     datashape           nturl2path          tabnanny
# _elementtree        datetime            numba               tabulate
# _functools          dateutil            numbergen           tarfile
# _hashlib            dbi                 numbers             tbb
# _heapq              dbm                 numexpr             tblib
# _imp                dde                 numpy               telnetlib
# _io                 debugpy             numpydoc            tempfile
# _json               decimal             odbc                tenacity
# _locale             decorator           onedal              terminado
# _lsprof             defusedxml          opcode              test
# _lzma               diff_match_patch    openpyxl            test_pycosat
# _markupbase         difflib             operator            text_unidecode
# _md5                dill                optparse            textdistance
# _msi                dis                 os                  textwrap
# _multibytecodec     distributed         packaging           this
# _multiprocessing    distutils           pandas              threading
# _nsis               docstring_to_markdown pandocfilters       threadpoolctl
# _opcode             doctest             panel               three_merge
# _operator           docutils            param               tifffile
# _osx_support        email               paramiko            time
# _overlapped         encodings           parsel              timeit
# _pickle             ensurepip           parso               timer
# _plotly_future_     entrypoints         partd               tinycss2
# _plotly_utils       enum                past                tkinter
# _py_abc             erfa                pathlib             tldextract
# _pydecimal          errno               pathspec            tlz
# _pyio               et_xmlfile          patsy               token
# _pyrsistent_version executing           pdb                 tokenize
# _pytest             fastjsonschema      pep8                toml
# _queue              faulthandler        perfmon             tomlkit
# _random             filecmp             pexpect             tomllib
# _sha1               fileinput           pickle              toolz
# _sha256             filelock            pickleshare         tornado
# _sha3               flake8              pickletools         tqdm
# _sha512             flask               pip                 trace
# _signal             fnmatch             pipes               traceback
# _sitebuiltins       fontTools           pkg_resources       tracemalloc
# _socket             fractions           pkginfo             traitlets
# _sqlite3            frozenlist          pkgutil             transformers
# _sre                fsspec              platform            tty
# _ssl                ftplib              platformdirs        turtle
# _stat               functools           plistlib            turtledemo
# _statistics         future              plotly              twisted
# _string             gc                  pluggy              types
# _strptime           genericpath         ply                 typing
# _struct             gensim              pooch               typing_extensions
# _symtable           getopt              poplib              uc_micro
# _system_path        getpass             posixpath           ujson
# _testbuffer         gettext             poyo                unicodedata
# _testcapi           glob                pprint              unidecode
# _testconsole        glob2               profile             unittest
# _testimportmultiple graphlib            prometheus_client   urllib
# _testinternalcapi   greenlet            prompt_toolkit      urllib3
# _testmultiphase     gzip                protego             uu
# _thread             h5py                pstats              uuid
# _threading_local    hashlib             psutil              venv
# _tkinter            heapdict            pty                 w3lib
# _tokenize           heapq               ptyprocess          warnings
# _tracemalloc        hmac                pure_eval           watchdog
# _typing             holoviews           pvectorc            wave
# _uuid               html                py                  wcwidth
# _warnings           http                py_compile          weakref
# _weakref            hvplot              pyarrow             webbrowser
# _weakrefset         hyperlink           pyasn1              webencodings
# _win32sysloader     idlelib             pyasn1_modules      websocket
# _winapi             idna                pyclbr              werkzeug
# _winxptheme         imagecodecs         pycodestyle         whatthepatch
# _xxsubinterpreters  imageio             pycosat             wheel
# _yaml               imagesize           pycparser           widgetsnbextension
# _zoneinfo           imaplib             pyct                win2kras
# abc                 imblearn            pycurl              win32api
# adodbapi            imghdr              pydispatch          win32clipboard
# afxres              imp                 pydoc               win32com
# aifc                importlib           pydoc_data          win32con
# aiobotocore         importlib_metadata  pydocstyle          win32console
# aiofiles            incremental         pyexpat             win32cred
# aiohttp             inflection          pyflakes            win32crypt
# aioitertools        iniconfig           pygments            win32cryptcon
# aiosignal           inspect             pylab               win32ctypes
# aiosqlite           intake              pylint              win32event
# alabaster           intervaltree        pylint_venv         win32evtlog
# anaconda_anon_usage io                  pyls_spyder         win32evtlogutil
# anaconda_catalogs   ipaddress           pylsp               win32file
# anaconda_navigator  ipykernel           pylsp_black         win32gui
# anaconda_project    ipykernel_launcher  pylsp_jsonrpc       win32gui_struct
# antigravity         ipython_genutils    pyodbc              win32help
# anyio               ipywidgets          pyparsing           win32inet
# appdirs             isapi               pyrsistent          win32inetcon
# argon2              isort               pytest              win32job
# argparse            isympy              pythoncom           win32lz
# array               itemadapter         pythonjsonlogger    win32net
# arrow               itemloaders         pytoolconfig        win32netcon
# ast                 itertools           pytz                win32pdh
# astroid             itsdangerous        pyviz_comms         win32pdhquery
# astropy             jedi                pywin               win32pdhutil
# asttokens           jellyfish           pywin32_bootstrap   win32pipe
# async_timeout       jinja2              pywin32_testutil    win32print
# asynchat            jinja2_time         pywintypes          win32process
# asyncio             jmespath            pywt                win32profile
# asyncore            joblib              qdarkstyle          win32ras
# atexit              json                qstylizer           win32rcparser
# atomicwrites        json5               qtawesome           win32security
# attr                jsonpatch           qtconsole           win32service
# attrs               jsonpointer         qtpy                win32serviceutil
# audioop             jsonschema          queue               win32timezone
# automat             jupyter             queuelib            win32trace
# autopep8            jupyter_client      quopri              win32traceutil
# babel               jupyter_console     random              win32transaction
# backcall            jupyter_core        rasutil             win32ts
# backports           jupyter_events      re                  win32ui
# base64              jupyter_server      regcheck            win32uiole
# bcrypt              jupyter_server_fileid regex               win32verstamp
# bdb                 jupyter_server_ydoc regutil             win32wnet
# binaryornot         jupyter_ydoc        repo_cli            win_inet_pton
# binascii            jupyterlab          reprlib             winerror
# binstar_client      jupyterlab_plotly   requests            winioctlcon
# bisect              jupyterlab_pygments requests_file       winnt
# black               jupyterlab_server   requests_toolbelt   winperf
# blackd              jupyterlab_widgets  rfc3339_validator   winpty
# bleach              jwt                 rfc3986_validator   winreg
# blib2to3            keyring             rlcompleter         winsound
# bokeh               keyword             rope                winxpgui
# boltons             kiwisolver          rtree               winxptheme
# boto3               lazy_loader         ruamel_yaml         wrapt
# botocore            lazy_object_proxy   runpy               wsgiref
# bottleneck          lib2to3             s3fs                xarray
# brotli              libarchive          s3transfer          xdrlib
# bs4                 libfuturize         sacremoses          xlwings
# builtins            libmambapy          sched               xml
# bz2                 libpasteurize       scipy               xmlrpc
# cProfile            lief                scrapy              xxlimited
# calendar            linecache           seaborn             xxlimited_35
# certifi             linkify_it          secrets             xxsubtype
# cffi                llvmlite            select              xyzservices
# cgi                 lmdb                selectors           y_py
# cgitb               locale              send2trash          yaml
# chardet             locket              service_identity    yapf
# charset_normalizer  logging             servicemanager      yapftests
# chunk               lxml                setuptools          yarl
# click               lz4                 shelve              ypy_websocket
# cloudpickle         lzma                shlex               zict
# clyent              mailbox             shutil              zipapp
# cmath               mailcap             signal              zipfile
# cmd                 markdown            sipbuild            zipimport
# code                markdown_it         site                zipp
# codecs              markupsafe          six                 zlib
# codeop              marshal             skimage             zmq
# collections         math                sklearn             zoneinfo
# colorama            matplotlib          sklearnex           zope
# colorcet            matplotlib_inline   slugify             zstandard
# colorsys            mccabe              smart_open
# comm                mdit_py_plugins     smtpd
# commctrl            mdurl               smtplib
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
#
# ✅ You’re on a modern Python version!

# %%
from PIL import Image
from IPython.display import display

img = Image.open(r"C:\\Users\\Sravanthi\\Pictures\\Screenshots\\Screenshot 2025-09-01 164652.png")
print("this is Disk Management after shrinking the volume and created the new partition D DRIVE")
display(img)

img1 = Image.open(r"C:\\Users\\Sravanthi\\Pictures\\Screenshots\\Screenshot 2025-09-01 164937.png")
print("This is the final folder structure of Course work in D DRIVE")
display(img1)

img2 = Image.open(r"C:\\Users\\Sravanthi\\Pictures\\Screenshots\\Screenshot 2025-09-01 165412.png")
print("This is the final folder structure.")
display(img2)
# Out:
# this is Disk Management after shrinking the volume and created the new partition D DRIVE
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=674x139>
# This is the final folder structure of Course work in D DRIVE
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=801x277>
# This is the final folder structure.
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=310x617>
